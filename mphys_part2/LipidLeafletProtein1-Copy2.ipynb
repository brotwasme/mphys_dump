# %%
import os.path
import numpy as np
import matplotlib.pyplot as plt
import scipy
import refnx
from refnx.dataset import ReflectDataset, Data1D
from refnx.analysis import Transform, CurveFitter, Objective, Model, Parameter, GlobalObjective
from refnx.reflect import SLD, Slab, ReflectModel#, LipidLeaflet
from refnx.reflect import LipidLeaflet as LipidLeafletNoProtein
# from sepObjectiveGO import getObjective as gO
# import make_sim_data as msd
# import lipidBilayerAsGiven.SLD_maker 
import data_in as di
from protein.ProteinBuiltOnLL3 import LipidLeafletWithProtien as LipidLeaflet
from protein.protrusion2 import Protrusion

from refnx._lib import flatten
from refnx._lib import unique as f_unique

print('refnx: %s\nscipy: %s\nnumpy: %s' % (refnx.version.version,
                   scipy.version.version, np.version.version))
# %matplotlib inline
SEED = 12345
# Out:
# refnx: 0.1.9
# scipy: 1.3.0
# numpy: 1.16.4

# %%
# dataD2o = Data1D(data=di.data_in("lipidBilayerData/54696_97_edit.txt"))
# dataD2o.name="d2o"
# dataPmw = Data1D(data=di.data_in("lipidBilayerData/54699_00_edit.txt"))
# dataPmw.name="pmw"

dataAcmw = Data1D(data=di.data_in("protein/54613_14edit.txt"))
dataAcmw.name="acm"
dataPmw = Data1D(data=di.data_in("protein/54616_17edit.txt"))
dataPmw.name="pmw"
dataD2o = Data1D(data=di.data_in("protein/10_11_d2o.txt"))
dataD2o.name="d2o"
plt.errorbar(dataAcmw.data[0],dataAcmw.data[1],dataAcmw.data[2])
plt.errorbar(dataPmw.data[0],dataPmw.data[1],dataPmw.data[2])
plt.errorbar(dataD2o.data[0],dataD2o.data[1],dataD2o.data[2])
plt.yscale("log")
plt.show()
# Out:
# csv
# cvs-collecting
# csv
# cvs-collecting
# csv
# cvs-collecting

# %%
name = "bilayer"

d2o = SLD(6.34, "D2O")
pmw = SLD(2.35, "Protein Matched Water")
acmw = SLD(0.00, "ACMW")
air = SLD(0.00, "Air")

d2o.real.setp(vary=True, bounds=(5.35, 6.35)) # bounds=(5.9, 6.35))
pmw.real.setp(vary=True, bounds=(1.35, 3.35))
acmw.real.setp(vary=True, bounds=(-0.56, 1))

apm = Parameter(value=50, name='%s - area_per_molecule' % name,
                bounds=(25, 100), vary=True)

#Define all the neutron b's
bc = 0.6646e-4  #Carbon
bo = 0.5804e-4  #Oxygen
bh = -0.3739e-4 #Hydrogen
bp = 0.513e-4   #Phosphorus
bn = 0.936e-4   #Nitrogen
bd = 0.6671e-4  #Deuterium

#Formulae of the molecule sections...
# CH2 = (1*bc) + (2*bh)
# CH = (1*bc) + (1*bh)
# CH3 = (1*bc) + (3*bh)
# D2O = (2*bd) + (1*bo)
# H2O = (2*bh) + (1*bo)

# Calculate mole fraction of D2O from the bulk SLD..
# d2o_molfr = (1/D2O-H2O)*(contrast*27.64)-H2O
# wMol = (d2o_molfr * D2O) + ((1-d2o_molfr)*H2O)

#sum b's of all the different fragments
b_tails = Parameter(value=(32*bc)+(64*bh),
                       name='%s - b_tails_real' % name)

sum_popc_heads = (10*bc)+(18*bh)+(8*bo)+(bp)+bn #new
sum_popg_heads = (8*bc)+(12*bh)+(10*bo)+(bp) # new
b_heads = Parameter(value=(3*(sum_popc_heads) + (sum_popg_heads))/4,
                        name='%s - b_heads_real' % name)

#monolayer compositions
#sum_m_tails = (34*CH2) + (2*CH3);
#sum_m_heads = (1*bn) + (2*CH3) + (Waters_per_headD * wMol);

#volumes of each fragment
# vCH2 = 27.7
# nCH2 = 30
# vCH3 = 54.6
vm_tails = Parameter(value=886.4,#(nCH2 * vCH2) + (2 * vCH3),
            name='%s - volume_tails' % name) #
vm_popc_heads = 331
vm_popg_heads = 291
vm_heads = Parameter(value=(3*(vm_popc_heads) + (vm_popg_heads))/4, # 331
            name='%s - volume_heads' % name)  #
vm_water = Parameter(value=29.7,
            name='%s - water_vm' % name)

#thickness
thickness_tails = Parameter(11, # 6., #value=vm_tails.value/apm.value,
            name='%s - thickness_tails' % name,# vary=False)
            bounds=(1,30),  #3, #(1-0.75)*vm_tails.value/apm.value,
                      #9), #(1+0.75)*vm_tails.value/apm.value),
               vary=True)
thickness_heads = Parameter(value= 6, #11., #vm_heads.value/apm.value,
            name='%s - thickness_heads' % name,# vary=False)
            bounds=(1,30),  #  9, #(1-0.75)*vm_heads.value/apm.value,
                      # 20), #(1+0.75)*vm_heads.value/apm.value),
               vary=True)

rough_head_tail = Parameter(value=2,
            name='%s - roughs' % name,
            bounds=(0,10), vary=True)

rough_top = Parameter(value=2,
            name='%s - roughs' % name,
            bounds=(0,10), vary=True)
# rough_bot = rough_top
# rough_head_ = Parameter(value=2.0,
#             name='%s - rough_bot' % name,
#             bounds=(0,10), vary=True)

waters_head_frac = Parameter(
            value=0.25,
            name="{} - Waters Head fraction".format(name),
            bounds=(0, 0.5), vary=True)

waters_tail_frac = Parameter(
            value=0.25,
            name="{} - Waters Tail fraction".format(name),
            bounds=(0, 0.5), vary=True)

# b_mscl = Parameter(
#             value= ,
#             name="{} - b_protein_real".format(name),
#             vary=False)

vm_mscl = Parameter(
            value=74937.5 + 19749,
            name="{} - volume_protein".format(name),
            vary=False)

PLRatio = Parameter(
            value= 0.75,
            name="{} - ratio protein to bilayer".format(name),
            bounds=(0, 1),vary=True)

# %%
# apm, b_heads, vm_heads, thickness_heads
# b_tails, vm_tails, thickness_tails, rough_head_tail
# rough_preceding_mono, head_solvent

# apm, b_heads, vm_heads, thickness_heads,
#  b_tails, vm_tails, thickness_tails, rough_head_tail,
#  rough_preceding_mono,
#  waters_head_frac, waters_tail_frac,
#  vm_mscl, PLRatio,
#  head_solvent=None, tail_solvent=None,
#  reverse_monolayer=False, name=''

# head_solvent_d2o = SLD(6.07, "D2O in bilayer")
# head_solvent_d2o.real.setp(6.07, vary=True, bounds=(5.35, 6.35))
upper_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
#     waters_head_frac, waters_tail_frac,
   vm_mscl, PLRatio,
                               d2o, d2o,
    reverse_monolayer=False, name="upper_lipid_d2o")

lower_lipid_d2o = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
#     waters_head_frac, waters_tail_frac,
    vm_mscl, PLRatio,
                               d2o, d2o,
    reverse_monolayer=True, name="lower_lipid_d2o")


# head_solvent_pmw = SLD(2.35, "Protein Matched Water in bilayer")
# head_solvent_pmw.real.setp(2.34, vary=True, bounds=(1.35, 3.35))
upper_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
#     waters_head_frac, waters_tail_frac,
    vm_mscl, PLRatio,
                               pmw, pmw,
    reverse_monolayer=False, name="upper_lipid_pmw")

lower_lipid_pmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
#     waters_head_frac, waters_tail_frac,
   vm_mscl, PLRatio,
                               pmw, pmw,
    reverse_monolayer=True, name="lower_lipid_pmw")


upper_lipid_acmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
#     waters_head_frac, waters_tail_frac,
    vm_mscl, PLRatio,
                                acmw, acmw,
    reverse_monolayer=False, name="upper_lipid_acmw")

lower_lipid_acmw = LipidLeaflet(apm, b_heads, vm_heads, thickness_heads,
    b_tails, vm_tails, thickness_tails, rough_top, rough_top,
#     waters_head_frac, waters_tail_frac,
    vm_mscl, PLRatio,
                                acmw, acmw,
    reverse_monolayer=True, name="lower_lipid_acmw")

# %%
name_m = "mono"
# APMD = Parameter(value=48, name='%s - area_per_molecule' % name_m,
#         bounds=(40,200), vary=True)

# # monolayer compositions
# m_tails = Parameter(value=(34*CH2) + (2*CH3),
#             name='%s - b_tails_real' % name_m)
# m_heads = Parameter(value=(1*bn) + (2*CH3),
#             name='%s - b_heads_real' % name_m)

# # monolayer volumes
# vm_m_tails = Parameter(value=vCH2*36,
#             name='%s - volume_tails' % name_m)
# vm_m_heads = Parameter(value=54.6,
#             name='%s - volume_heads' % name_m)

# # monolayer thicknesses
# tail_thick_m = Parameter(value=vm_m_tails.value / APMD.value,
#             name='%s - thickness_tails' % name_m,
#             bounds=(1,#(1-0.75)*vm_m_tails.value / APMD.value,
#                     30),#(1+0.75)*vm_m_tails.value / APMD.value),
#                vary=True)
# head_thick_m = Parameter(value=vm_m_heads.value / APMD.value,
#             name='%s - thickness heads' % name_m,
#             bounds=(1,#(1-0.75)*vm_m_heads.value / APMD.value,
#                     30),#(1+0.75)*vm_m_heads.value / APMD.value),
#                vary=True)

# roughness_m =  Parameter(value=5.8,
#             name='%s - roughness' % name_m,
#             bounds=(0,10), vary=True)

# %%
# firstlayerd = SLD(0, "d20 first layer")
# firstlayerd.real.setp(vary=True, bounds=(-1, 6.35))
# firstlayerp = SLD(0, "pmw first layer")
# firstlayerp.real.setp(vary=True, bounds=(-1, 6.35))
# firstlayera = SLD(0, "acmw first layer")
# firstlayera.real.setp(vary=True, bounds=(-1, 6.35))
# secondlayerd = SLD(0, "d20 second layer")
# secondlayerd.real.setp(vary=True, bounds=(-1, 6.35))
# secondlayerp = SLD(0, "pmw second layer")
# secondlayerp.real.setp(vary=True, bounds=(-1, 6.35))
# secondlayera = SLD(0, "acmw second layer")
# secondlayera.real.setp(vary=True, bounds=(-1, 6.35))

# m_air_in_tail = air
# m_head_solvent_d2o = d2o
# m_head_solvent_pmw = pmw
# # m_head_solvent_acmw = acmw
# dodab_solv = SLD(0.00, "dodab solv in tail")
# dodab_solv.real.setp(vary=True, bounds=(-1, 6.35))

# dodab_d2o = LipidLeafletNoProtein(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
# thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
# thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
# rough_preceding_mono=roughness_m, head_solvent=m_head_solvent_d2o, tail_solvent=dodab_solv,
#                                   reverse_monolayer=True) #mono

# dodab_pmw = LipidLeafletNoProtein(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
# thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
# thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
# rough_preceding_mono=roughness_m, head_solvent=m_head_solvent_pmw, tail_solvent=dodab_solv,
#                                   reverse_monolayer=True) #mono

# dodab_acmw = LipidLeafletNoProtein(apm=APMD, b_heads=m_heads, vm_heads=vm_m_heads,
# thickness_heads=head_thick_m, b_tails=m_tails, vm_tails=vm_m_tails,
# thickness_tails=tail_thick_m, rough_head_tail=roughness_m,
# rough_preceding_mono=roughness_m, head_solvent=m_head_solvent_acmw, tail_solvent=m_air_in_tail,
#                                   reverse_monolayer=True) #mono

# %%
# to changing to
solution_thickness = Parameter(value=14.3, bounds=(6, 25), vary=True,
            name='thickness_solution')
# solution_thickness2 = Parameter(value=14.3, bounds=(6, 25), vary=True,
#             name='thickness_solution2')

# rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
#             name='rough_preceding_solution')


rough_preceding_solution = Parameter(value=4.6, bounds=(0, 20), vary=True,
            name='rough_preceding_solution')#, constraint=)

# dodab_thick1 = Parameter(value=14.3, bounds=(0.1, 25), vary=True,
#             name='thickness_solution')
# dodab_thick2 = Parameter(value=14.3, bounds=(0.1, 25), vary=True,
#             name='thickness_solution')

structure_d2o  = air(0, 0) | d2o(solution_thickness, rough_preceding_solution)  | upper_lipid_d2o  | lower_lipid_d2o  | d2o(solution_thickness, rough_top)
structure_pmw  = air(0, 0) | pmw(solution_thickness, rough_preceding_solution)  | upper_lipid_pmw  | lower_lipid_pmw  | pmw(solution_thickness, rough_top)
structure_acmw = air(0, 0) | acmw(solution_thickness, rough_preceding_solution) | upper_lipid_acmw | lower_lipid_acmw | acmw(solution_thickness, rough_top)

# structure_d2o  = air(0, 0) | d2o(solution_thickness, rough_preceding_solution)  | upper_lipid_d2o  | lower_lipid_d2o  | d2o(solution_thickness, rough_preceding_solution)
# structure_pmw  = air(0, 0) | pmw(solution_thickness, rough_preceding_solution)  | upper_lipid_pmw  | lower_lipid_pmw  | pmw(solution_thickness, rough_preceding_solution)
# structure_acmw = air(0, 0) | acmw(solution_thickness, rough_preceding_solution) | upper_lipid_acmw | lower_lipid_acmw | acmw(solution_thickness, rough_preceding_solution)

structure_d2o.name = "d2o"
structure_pmw.name = "protein matched water"
# structure_acmw.name = "ACMW"

plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
plt.xlabel('distance / $\AA$')
# plt.plot(*structure_acmw.sld_profile(),label="structure_acmw")
# plt.ylabel('SLD /$10^{-6} \AA^{-2}$')
# plt.xlabel('distance / $\AA$')
plt.show();
print(structure_d2o.parameters)
print(structure_pmw.parameters)
# print(structure_acmw.parameters)
# Out:
# ________________________________________________________________________________
# Parameters: 'Structure - d2o'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=50          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=50          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.34          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - protein matched water'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=4.6          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=50          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=50          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.75          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=2.35          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=2          , bounds=[0, 10]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>

# %%
# right_protrusion_d2o.parameters

# %%
# print(structure_acmw.slabs())
# print(structure_pmw.slabs())
# print(structure_d2o.slabs())

def logp_extra(model=None, data=None):
    returns = 0
#     if rough_top.value > thickness_heads.value:
#         returns += -np.inf
#         print("rough, thickness: ", rough_top.value, thickness_heads.value)
    if choose==2:
        if upper_lipid_d2o.logp() == -np.inf or upper_lipid_pmw.logp() == -np.inf or upper_lipid_acmw.logp() == -np.inf:
            returns += -np.inf
    return returns

# %%
scale=0.5538
print(dataD2o.y.max(), dataPmw.y.max())#, dataAcmw.y.max())
print(dataD2o.y.min(), dataPmw.y.min())#, dataAcmw.y.min())
model1 = ReflectModel(structure_d2o)
model1.scale.setp(scale, vary=True, bounds=(0, 1))#0.25, 1)) #1./dataD2o.y.max()
if dataD2o.y.min()<0:
    d2oUpBound = dataD2o.y.min() * 0.2
    d2oLoBound = dataD2o.y.min() * 1.8
else:
    d2oUpBound = dataD2o.y.min() * 1.8
    d2oLoBound = dataD2o.y.min() * 0.2
model1.bkg.setp(dataD2o.y.min(),vary=True,bounds=(d2oLoBound, d2oUpBound))

model2 = ReflectModel(structure_pmw)
model2.scale.setp(scale, vary=True, bounds=(0, 1))#0.25, 1))#(1./dataPmw.y.max(), vary=False)
if dataPmw.y.min()<0:
    pmwUpBound = dataPmw.y.min() * 0.2
    pmwLoBound = dataPmw.y.min() * 1.8
else:
    pmwUpBound = dataPmw.y.min() * 1.8
    pmwLoBound = dataPmw.y.min() * 0.2
model2.bkg.setp(dataPmw.y.min(),vary=True,bounds=(pmwLoBound, pmwUpBound))

model3 = ReflectModel(structure_acmw)
model3.scale.setp(scale, vary=True, bounds=(0, 1))#0.25, 1)) #1./dataAcmw.y.max(), vary=False)
if dataAcmw.y.min()<0:
    acmwUpBound = dataAcmw.y.min() * 0.2
    acmwLoBound = dataAcmw.y.min() * 1.8
else:
    acmwUpBound = dataAcmw.y.min() * 1.8
    acmwLoBound = dataAcmw.y.min() * 0.2
model3.bkg.setp(dataAcmw.y.min(),vary=True,bounds=(acmwLoBound, acmwUpBound))



objective1 = Objective(model1, dataD2o, transform=Transform("logY"))#, logp_extra =logp_extra)
objective2 = Objective(model2, dataPmw, transform=Transform("logY"))#, logp_extra =logp_extra)
objective3 = Objective(model3, dataAcmw, transform=Transform("logY"))#, logp_extra =logp_extra)
gobjective = GlobalObjective([objective1,objective2,objective3])
gobjective.logp_extra = logp_extra
# Out:
# 0.562 0.0655
# 1.8e-06 3.02e-06

# %%
print("")
print("logp:",gobjective.logp())
[[print(i,param.name+":",param.value, param.bounds,"logp:", param.logp())] for i,param in enumerate(gobjective.varying_parameters())];
# print
# [[print(i,param)] for i,param in enumerate(gobjective.parameters)];# if "area_per_molecule" in param.name];
# gobjective.parameters
print()
# [[print(i,param.name)] for i,param in enumerate(gobjective.parameters)];# if "area" in param
list(print(p) for p in f_unique(flatten(gobjective.parameters)) if "thi" in p.name or "ap" in p.name);
# upper_lipid_d2o.done()
# Out:
# logp: -inf
# 0 scale: 0.5538 [0, 1] logp: 0.0
# 1 bkg: 1.8e-06 [3.6e-07, 3.24e-06] logp: 12.75772026381642
# 2 thickness_solution: 14.3 [6, 25] logp: -2.9444389791664407
# 3 D2O - sld: 6.34 [5.35, 6.35] logp: 0.0
# 4 rough_preceding_solution: 4.6 [0, 20] logp: -2.995732273553991
# 5 bilayer - area_per_molecule: 50.0 [25, 100] logp: -4.31748811353631
# 6 bilayer - thickness_heads: 6.0 [1, 30] logp: -3.367295829986474
# 7 bilayer - thickness_tails: 11.0 [1, 30] logp: -3.367295829986474
# 8 bilayer - roughs: 2.0 [0, 10] logp: -2.3025850929940455
# 9 bilayer - ratio protein to bilayer: 0.75 [0, 1] logp: 0.0
# 10 scale: 0.5538 [0, 1] logp: 0.0
# 11 bkg: 3.02e-06 [6.040000000000001e-07, 5.436e-06] logp: 12.24025009733176
# 12 Protein Matched Water - sld: 2.35 [1.35, 3.35] logp: -0.6931471805599453
# 13 scale: 0.5538 [0, 1] logp: 0.0
# 14 bkg: 1.73e-06 [3.46e-07, 3.114e-06] logp: 12.79738552020885
# 15 ACMW - sld: 0.0 [-0.56, 1] logp: -0.4446858212614458
#
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'thickness_solution', value=14.3          , bounds=[6, 25]>
# <Parameter:'bilayer - thickness_heads', value=6          , bounds=[1, 30]>
# <Parameter:'bilayer - thickness_tails', value=11          , bounds=[1, 30]>
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>

# %%
# %%time
choose = 2
place = "LipidLeafletProtein1-Copy2"
if choose==0:
    fitter = CurveFitter(gobjective)
    res = fitter.fit("differential_evolution", target="nlpost")#, seed=SEED)
if choose==1:
    fitter = CurveFitter(gobjective)
    fitter.sample(400)
    fitter.reset()
    res = fitter.sample(15, nthin=100)
if choose==2:
    from dynesty import DynamicNestedSampler
    from dynesty import plotting as dyplot
    from CFitter2 import CFitter
    fitter = CFitter(gobjective)
    # DynamicNestedSampler
    DNSampler = DynamicNestedSampler(fitter.logl, fitter.priorTransform, fitter.nDim())
    DNSampler.run_nested(dlogz_init=0.05) # was 0.01
    res1 = DNSampler.results
    from dynesty import plotting as dyplot
    from saveDynestyRun import save_obj
    save_obj(res1, place)
    fitter.logl(fitter._best)
    save_obj(fitter, place+"fitter")
if choose==3:
    from saveDynestyRun import load_obj
    from dynesty import plotting as dyplot
    res1 = load_obj(place)
    fitter = load_obj(place+"fitter")
    fitter.logl(fitter._best)
    gobjective = fitter.objective
print("done")
# Out:
# 1396it [02:30,  2.01it/s, batch: 0 | bound: 1 | nc: 25 | ncall: 13575 | eff(%):  9.918 | loglstar:   -inf < -58946.350 <    inf | logz: -58955.361 +/-    nan | dlogz: 44077.203 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 11623it [1:07:09,  2.53it/s, batch: 0 | bound: 161 | nc: 25 | ncall: 270789 | eff(%):  4.284 | loglstar:   -inf < -654.070 <    inf | logz: -681.233 +/-    nan | dlogz: 418.422 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12333it [1:12:19,  2.51it/s, batch: 0 | bound: 173 | nc: 25 | ncall: 290921 | eff(%):  4.232 | loglstar:   -inf < -531.008 <    inf | logz: -560.102 +/-    nan | dlogz: 313.692 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12436it [1:13:12,  1.32s/it, batch: 0 | bound: 176 | nc: 86 | ncall: 294443 | eff(%):  4.216 | loglstar:   -inf < -514.717 <    inf | logz: -543.887 +/-    nan | dlogz: 297.250 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 12788it [1:15:44,  1.90it/s, batch: 0 | bound: 182 | nc: 66 | ncall: 304377 | eff(%):  4.194 | loglstar:   -inf < -464.708 <    inf | logz: -494.399 +/-    nan | dlogz: 247.033 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13116it [1:18:25,  2.58it/s, batch: 0 | bound: 188 | nc: 25 | ncall: 314932 | eff(%):  4.158 | loglstar:   -inf < -422.225 <    inf | logz: -452.300 +/-    nan | dlogz: 239.429 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13323it [1:20:13,  2.63it/s, batch: 0 | bound: 191 | nc: 25 | ncall: 321808 | eff(%):  4.134 | loglstar:   -inf < -393.915 <    inf | logz: -424.402 +/-    nan | dlogz: 226.826 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13496it [1:21:39,  2.39it/s, batch: 0 | bound: 194 | nc: 25 | ncall: 327191 | eff(%):  4.119 | loglstar:   -inf < -376.367 <    inf | logz: -407.135 +/-    nan | dlogz: 247.067 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13645it [1:23:06,  2.43it/s, batch: 0 | bound: 197 | nc: 25 | ncall: 332955 | eff(%):  4.092 | loglstar:   -inf < -361.137 <    inf | logz: -392.220 +/-    nan | dlogz: 231.852 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 13882it [1:25:01,  2.59it/s, batch: 0 | bound: 201 | nc: 25 | ncall: 340362 | eff(%):  4.073 | loglstar:   -inf < -341.001 <    inf | logz: -372.484 +/-    nan | dlogz: 211.632 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14017it [1:26:22,  2.25it/s, batch: 0 | bound: 204 | nc: 25 | ncall: 345651 | eff(%):  4.049 | loglstar:   -inf < -328.355 <    inf | logz: -360.382 +/-    nan | dlogz: 199.300 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 14148it [1:28:07,  2.40it/s, batch: 0 | bound: 207 | nc: 25 | ncall: 352900 | eff(%):  4.003 | loglstar:   -inf < -315.232 <    inf | logz: -347.461 +/-    nan | dlogz: 186.098 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14308it [1:29:38,  2.56it/s, batch: 0 | bound: 211 | nc: 25 | ncall: 358602 | eff(%):  3.984 | loglstar:   -inf < -302.687 <    inf | logz: -335.170 +/-    nan | dlogz: 173.487 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14462it [1:30:53,  2.45it/s, batch: 0 | bound: 214 | nc: 25 | ncall: 363533 | eff(%):  3.973 | loglstar:   -inf < -291.367 <    inf | logz: -323.952 +/-    nan | dlogz: 182.031 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14512it [1:31:37,  2.57it/s, batch: 0 | bound: 216 | nc: 25 | ncall: 366450 | eff(%):  3.955 | loglstar:   -inf < -287.382 <    inf | logz: -320.037 +/-    nan | dlogz: 178.015 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14685it [1:33:12,  2.40it/s, batch: 0 | bound: 220 | nc: 25 | ncall: 372518 | eff(%):  3.937 | loglstar:   -inf < -275.195 <    inf | logz: -307.745 +/-    nan | dlogz: 165.347 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14860it [1:34:59,  2.48it/s, batch: 0 | bound: 224 | nc: 25 | ncall: 379525 | eff(%):  3.910 | loglstar:   -inf < -263.412 <    inf | logz: -296.482 +/-    nan | dlogz: 166.002 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 14996it [1:36:17,  2.70it/s, batch: 0 | bound: 227 | nc: 25 | ncall: 384575 | eff(%):  3.894 | loglstar:   -inf < -254.555 <    inf | logz: -287.635 +/-    nan | dlogz: 156.868 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15618it [1:41:08,  2.46it/s, batch: 0 | bound: 237 | nc: 25 | ncall: 402108 | eff(%):  3.879 | loglstar:   -inf < -217.451 <    inf | logz: -251.799 +/-    nan | dlogz: 119.791 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 15619it [1:41:25,  5.55s/it, batch: 0 | bound: 238 | nc: 1151 | ncall: 403259 | eff(%):  3.868 | loglstar:   -inf < -217.331 <    inf | logz: -251.751 +/-    nan | dlogz: 119.742 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15823it [1:43:19,  2.59it/s, batch: 0 | bound: 241 | nc: 25 | ncall: 410338 | eff(%):  3.851 | loglstar:   -inf < -207.097 <    inf | logz: -241.811 +/-    nan | dlogz: 109.391 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 15888it [1:44:11,  2.48it/s, batch: 0 | bound: 243 | nc: 25 | ncall: 413942 | eff(%):  3.834 | loglstar:   -inf < -203.314 <    inf | logz: -238.324 +/-    nan | dlogz: 105.783 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16408it [1:48:29,  2.56it/s, batch: 0 | bound: 251 | nc: 25 | ncall: 430713 | eff(%):  3.805 | loglstar:   -inf < -179.923 <    inf | logz: -215.561 +/-    nan | dlogz: 92.009 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 16410it [1:48:42,  3.54s/it, batch: 0 | bound: 252 | nc: 425 | ncall: 431894 | eff(%):  3.795 | loglstar:   -inf < -179.911 <    inf | logz: -215.493 +/-    nan | dlogz: 91.937 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16547it [1:50:01,  2.49it/s, batch: 0 | bound: 254 | nc: 25 | ncall: 437050 | eff(%):  3.782 | loglstar:   -inf < -173.322 <    inf | logz: -209.499 +/-    nan | dlogz: 118.844 >  0.050] C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16747it [1:52:00,  2.73it/s, batch: 0 | bound: 258 | nc: 25 | ncall: 444899 | eff(%):  3.760 | loglstar:   -inf < -164.805 <    inf | logz: -201.219 +/-    nan | dlogz: 110.156 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16770it [1:52:42,  2.48it/s, batch: 0 | bound: 260 | nc: 25 | ncall: 448539 | eff(%):  3.735 | loglstar:   -inf < -163.947 <    inf | logz: -200.395 +/-    nan | dlogz: 109.286 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16806it [1:53:18,  2.48it/s, batch: 0 | bound: 262 | nc: 25 | ncall: 451470 | eff(%):  3.718 | loglstar:   -inf < -162.349 <    inf | logz: -199.008 +/-    nan | dlogz: 107.832 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16839it [1:54:21,  2.52it/s, batch: 0 | bound: 264 | nc: 25 | ncall: 456454 | eff(%):  3.685 | loglstar:   -inf < -160.942 <    inf | logz: -197.566 +/-    nan | dlogz: 106.321 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 16960it [1:55:45,  2.48it/s, batch: 0 | bound: 267 | nc: 25 | ncall: 462148 | eff(%):  3.666 | loglstar:   -inf < -156.250 <    inf | logz: -193.079 +/-    nan | dlogz: 101.591 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17401it [1:59:14,  2.59it/s, batch: 0 | bound: 274 | nc: 25 | ncall: 475308 | eff(%):  3.657 | loglstar:   -inf < -138.937 <    inf | logz: -176.439 +/-    nan | dlogz: 84.062 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 17765it [2:02:11,  2.50it/s, batch: 0 | bound: 280 | nc: 25 | ncall: 486528 | eff(%):  3.648 | loglstar:   -inf < -127.499 <    inf | logz: -165.607 +/-    nan | dlogz: 72.499 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18381it [2:06:47,  2.42it/s, batch: 0 | bound: 290 | nc: 25 | ncall: 504454 | eff(%):  3.640 | loglstar:   -inf < -109.097 <    inf | logz: -148.372 +/-    nan | dlogz: 56.902 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18480it [2:08:37,  2.43it/s, batch: 0 | bound: 293 | nc: 25 | ncall: 511743 | eff(%):  3.608 | loglstar:   -inf < -106.298 <    inf | logz: -145.861 +/-    nan | dlogz: 54.196 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 18721it [2:10:41,  2.51it/s, batch: 0 | bound: 298 | nc: 25 | ncall: 520121 | eff(%):  3.596 | loglstar:   -inf < -100.307 <    inf | logz: -140.249 +/-    nan | dlogz: 48.099 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19506it [2:16:23,  2.53it/s, batch: 0 | bound: 310 | nc: 25 | ncall: 541712 | eff(%):  3.597 | loglstar:   -inf < -82.733 <    inf | logz: -123.876 +/-    nan | dlogz: 45.348 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19577it [2:17:50,  2.69it/s, batch: 0 | bound: 312 | nc: 25 | ncall: 548042 | eff(%):  3.569 | loglstar:   -inf < -81.249 <    inf | logz: -122.564 +/-    nan | dlogz: 43.894 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19693it [2:19:05,  2.60it/s, batch: 0 | bound: 315 | nc: 25 | ncall: 552878 | eff(%):  3.559 | loglstar:   -inf < -79.153 <    inf | logz: -120.670 +/-    nan | dlogz: 50.628 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 19825it [2:20:39,  2.67it/s, batch: 0 | bound: 318 | nc: 25 | ncall: 559416 | eff(%):  3.541 | loglstar:   -inf < -76.799 <    inf | logz: -118.456 +/-    nan | dlogz: 48.149 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20014it [2:22:24,  2.56it/s, batch: 0 | bound: 322 | nc: 25 | ncall: 566251 | eff(%):  3.531 | loglstar:   -inf < -73.451 <    inf | logz: -115.461 +/-    nan | dlogz: 44.775 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20226it [2:24:46,  2.59it/s, batch: 0 | bound: 326 | nc: 25 | ncall: 575209 | eff(%):  3.513 | loglstar:   -inf < -69.871 <    inf | logz: -112.315 +/-    nan | dlogz: 41.206 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20740it [2:29:20,  2.57it/s, batch: 0 | bound: 334 | nc: 25 | ncall: 593305 | eff(%):  3.493 | loglstar:   -inf < -61.245 <    inf | logz: -104.520 +/-    nan | dlogz: 32.517 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# 20741it [2:29:34,  4.30s/it, batch: 0 | bound: 335 | nc: 1079 | ncall: 594384 | eff(%):  3.487 | loglstar:   -inf < -61.216 <    inf | logz: -104.508 +/-    nan | dlogz: 32.503 >  0.050]C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 20795it [2:30:17,  2.84it/s, batch: 0 | bound: 336 | nc: 25 | ncall: 597282 | eff(%):  3.479 | loglstar:   -inf < -60.426 <    inf | logz: -103.838 +/-    nan | dlogz: 31.725 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21017it [2:32:17,  2.61it/s, batch: 0 | bound: 340 | nc: 25 | ncall: 605782 | eff(%):  3.467 | loglstar:   -inf < -57.055 <    inf | logz: -100.947 +/-    nan | dlogz: 32.023 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21359it [2:35:23,  2.56it/s, batch: 0 | bound: 346 | nc: 25 | ncall: 617917 | eff(%):  3.454 | loglstar:   -inf < -52.640 <    inf | logz: -96.901 +/-    nan | dlogz: 30.014 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21643it [2:37:56,  2.52it/s, batch: 0 | bound: 351 | nc: 25 | ncall: 627950 | eff(%):  3.444 | loglstar:   -inf < -48.998 <    inf | logz: -93.884 +/-    nan | dlogz: 26.430 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21766it [2:39:16,  2.70it/s, batch: 0 | bound: 354 | nc: 25 | ncall: 633126 | eff(%):  3.435 | loglstar:   -inf < -47.566 <    inf | logz: -92.683 +/-    nan | dlogz: 24.983 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 21969it [2:41:19,  2.59it/s, batch: 0 | bound: 358 | nc: 25 | ncall: 641729 | eff(%):  3.421 | loglstar:   -inf < -45.165 <    inf | logz: -90.615 +/-    nan | dlogz: 22.509 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22107it [2:43:32,  2.52it/s, batch: 0 | bound: 361 | nc: 25 | ncall: 650633 | eff(%):  3.395 | loglstar:   -inf < -43.711 <    inf | logz: -89.370 +/-    nan | dlogz: 20.987 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22468it [2:46:55,  2.59it/s, batch: 0 | bound: 367 | nc: 25 | ncall: 663288 | eff(%):  3.385 | loglstar:   -inf < -40.091 <    inf | logz: -86.310 +/-    nan | dlogz: 20.247 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 22634it [2:49:39,  2.58it/s, batch: 0 | bound: 371 | nc: 25 | ncall: 675345 | eff(%):  3.349 | loglstar:   -inf < -38.326 <    inf | logz: -84.962 +/-    nan | dlogz: 18.568 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 23568it [2:56:36,  2.62it/s, batch: 0 | bound: 385 | nc: 25 | ncall: 702965 | eff(%):  3.350 | loglstar:   -inf < -31.864 <    inf | logz: -79.731 +/-    nan | dlogz: 14.452 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 23739it [2:58:22,  2.60it/s, batch: 0 | bound: 389 | nc: 25 | ncall: 710423 | eff(%):  3.339 | loglstar:   -inf < -30.778 <    inf | logz: -78.983 +/-    nan | dlogz: 16.564 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24178it [3:02:06,  2.52it/s, batch: 0 | bound: 396 | nc: 25 | ncall: 725792 | eff(%):  3.329 | loglstar:   -inf < -27.640 <    inf | logz: -76.926 +/-    nan | dlogz: 15.049 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24246it [3:04:28,  2.53it/s, batch: 0 | bound: 398 | nc: 25 | ncall: 734665 | eff(%):  3.298 | loglstar:   -inf < -27.234 <    inf | logz: -76.580 +/-    nan | dlogz: 14.567 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 24900it [3:09:36,  2.51it/s, batch: 0 | bound: 408 | nc: 25 | ncall: 754516 | eff(%):  3.298 | loglstar:   -inf < -23.689 <    inf | logz: -73.949 +/-    nan | dlogz: 12.415 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25342it [3:13:07,  2.71it/s, batch: 0 | bound: 415 | nc: 25 | ncall: 768326 | eff(%):  3.296 | loglstar:   -inf < -21.594 <    inf | logz: -72.565 +/-    nan | dlogz: 10.148 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 25531it [3:15:11,  2.47it/s, batch: 0 | bound: 419 | nc: 25 | ncall: 776152 | eff(%):  3.287 | loglstar:   -inf < -20.862 <    inf | logz: -72.068 +/-    nan | dlogz:  9.445 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 28594it [3:36:30,  2.54it/s, batch: 0 | bound: 461 | nc: 25 | ncall: 856795 | eff(%):  3.335 | loglstar:   -inf < -10.976 <    inf | logz: -67.102 +/-    nan | dlogz:  3.533 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 28968it [3:41:56,  2.46it/s, batch: 0 | bound: 467 | nc: 25 | ncall: 877956 | eff(%):  3.298 | loglstar:   -inf < -10.216 <    inf | logz: -66.860 +/-    nan | dlogz:  2.956 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 29101it [3:44:18,  2.82it/s, batch: 0 | bound: 470 | nc: 25 | ncall: 889926 | eff(%):  3.268 | loglstar:   -inf < -9.928 <    inf | logz: -66.785 +/-    nan | dlogz:  2.636 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 30857it [3:57:36,  2.45it/s, batch: 0 | bound: 495 | nc: 25 | ncall: 943156 | eff(%):  3.270 | loglstar:   -inf < -7.358 <    inf | logz: -66.267 +/-    nan | dlogz:  0.702 >  0.050]  C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31340it [4:04:36,  2.51it/s, batch: 0 | bound: 503 | nc: 25 | ncall: 969486 | eff(%):  3.231 | loglstar:   -inf < -6.781 <    inf | logz: -66.217 +/-    nan | dlogz:  0.391 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31707it [4:10:05,  2.52it/s, batch: 0 | bound: 509 | nc: 25 | ncall: 993374 | eff(%):  3.190 | loglstar:   -inf < -6.351 <    inf | logz: -66.191 +/-    nan | dlogz:  0.216 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 31952it [4:13:54,  2.63it/s, batch: 0 | bound: 514 | nc: 25 | ncall: 1010270 | eff(%):  3.161 | loglstar:   -inf < -6.103 <    inf | logz: -66.178 +/-    nan | dlogz:  0.146 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32177it [4:17:24,  2.64it/s, batch: 0 | bound: 518 | nc: 25 | ncall: 1026178 | eff(%):  3.134 | loglstar:   -inf < -5.928 <    inf | logz: -66.169 +/-    nan | dlogz:  0.116 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 32388it [4:21:14,  2.50it/s, batch: 0 | bound: 522 | nc: 25 | ncall: 1043032 | eff(%):  3.104 | loglstar:   -inf < -5.746 <    inf | logz: -66.162 +/-    nan | dlogz:  0.077 >  0.050]   C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:219: UserWarning: Random number generation appears to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random number generation appears to be "
# C:\Users\John\Anaconda3\envs\refnx\lib\site-packages\dynesty\sampling.py:241: UserWarning: Random walk proposals appear to be extremely inefficient. Adjusting the scale-factor accordingly.
#   warnings.warn("Random walk proposals appear to be "
# 49961it [6:02:13,  2.30it/s, batch: 5 | bound: 728 | nc: 25 | ncall: 1484260 | eff(%):  3.366 | loglstar: -15.524 < -3.187 < -3.975 | logz: -66.097 +/-    nan | stop:  0.925]
# done
# Wall time: 6h 2min 14s

# %%
# print(gobjective.parameters,"\n++++++++++++++++++++++++++++++++++++++++++++++++++++")
# fitter.logl(fitter._best)

[[print(param)] for param in gobjective.parameters]#varying_parameters()]

[[print(param)] for param in gobjective.varying_parameters()];
# Out:
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.549179          , bounds=[0, 1]>
# <Parameter:     'bkg'     , value=1.02725e-06          , bounds=[3.6e-07, 3.24e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - d2o'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=1.03206          , bounds=[0, 20]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_d2o'
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_d2o - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters:      'D2O'
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter: 'D2O - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'D2O - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.603869          , bounds=[0, 1]>
# <Parameter:     'bkg'     , value=2.97694e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - protein matched water'
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=1.03206          , bounds=[0, 20]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_pmw'
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_pmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'Protein Matched Water'
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:'Protein Matched Water - isld', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'Protein Matched Water - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# ________________________________________________________________________________
# Parameters: 'instrument parameters'
# <Parameter:    'scale'    , value=0.139747          , bounds=[0, 1]>
# <Parameter:     'bkg'     , value=2.66235e-06          , bounds=[3.46e-07, 3.114e-06]>
# <Parameter:'dq - resolution', value=5 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'Structure - '
# ________________________________________________________________________________
# Parameters:      'Air'
# <Parameter: 'Air - thick' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:  'Air - sld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - isld'  , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter: 'Air - rough' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'Air - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'rough_preceding_solution', value=1.03206          , bounds=[0, 20]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters: 'upper_lipid_acmw'
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_acmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'upper_lipid_acmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters: 'lower_lipid_acmw'
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_acmw - b_heads_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'lower_lipid_acmw - b_tails_imag', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_tails', value=886.4 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# ________________________________________________________________________________
# Parameters:       ''
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - volume_protein', value=94686.5 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# ________________________________________________________________________________
# Parameters:     'ACMW'
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>
# <Parameter: 'ACMW - isld' , value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'ACMW - volfrac solvent', value=0 (fixed)  , bounds=[-inf, inf]>
# <Parameter:    'scale'    , value=0.549179          , bounds=[0, 1]>
# <Parameter:     'bkg'     , value=1.02725e-06          , bounds=[3.6e-07, 3.24e-06]>
# <Parameter:'thickness_solution', value=6.31966          , bounds=[6, 25]>
# <Parameter:  'D2O - sld'  , value=6.10777          , bounds=[5.35, 6.35]>
# <Parameter:'rough_preceding_solution', value=1.03206          , bounds=[0, 20]>
# <Parameter:'bilayer - area_per_molecule', value=53.1778          , bounds=[25, 100]>
# <Parameter:'bilayer - thickness_heads', value=9.93403          , bounds=[1, 30]>
# <Parameter:'bilayer - thickness_tails', value=16.669          , bounds=[1, 30]>
# <Parameter:'bilayer - roughs', value=5.72497          , bounds=[0, 10]>
# <Parameter:'bilayer - ratio protein to bilayer', value=0.999999          , bounds=[0, 1]>
# <Parameter:    'scale'    , value=0.603869          , bounds=[0, 1]>
# <Parameter:     'bkg'     , value=2.97694e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# <Parameter:'Protein Matched Water - sld', value=1.72646          , bounds=[1.35, 3.35]>
# <Parameter:    'scale'    , value=0.139747          , bounds=[0, 1]>
# <Parameter:     'bkg'     , value=2.66235e-06          , bounds=[3.46e-07, 3.114e-06]>
# <Parameter: 'ACMW - sld'  , value=0.899351          , bounds=[-0.56, 1]>

# %%
if choose==2 or choose==3:
#     from saveDynestyRun import load_obj
#     from dynesty import plotting as dyplot
#     from saveDynestyRun import save_obj
#     place = "LipidLeaflet1roughThickDy"
#     save_obj(res1, place)
#     res1 = load_obj(place)
    print(res1)
else:
    print(res)

# res2 = load_obj("LipidLeaflet1roughThickDy")
# [['bkg', nan],
#  ['thickness_solution', nan],
#  ['D2O - sld', nan],
#  ['rough_preceding_solution', nan],
#  ['bilayer - area_per_molecule', nan],
#  ['bilayer - thickness_heads', nan],
#  ['bilayer - thickness_tails', nan],
#  ['bilayer - rough_top', nan],
#  ['bilayer - Waters Per Head', nan],
#  ['bilayer - Waters Per Tail', nan],
#  ['bilayer - ratio protein to bilayer', nan],
#  ['bkg', nan],
#  ['Protein Matched Water - sld', nan],
#  ['bkg', nan],
#  ['ACMW - sld', nan]]
# Out:
#          niter: 49961
#          ncall: array([ 1,  2,  6, ..., 25, 25, 25])
#            eff: 3.3660544648511714
#        samples: array([[2.20273962e-01, 2.51964933e-06, 1.46836629e+01, ...,
#         2.17728296e-01, 2.48050334e-06, 5.18211669e-01],
#        [5.48518467e-01, 2.09365236e-06, 1.05587400e+01, ...,
#         2.62921694e-01, 4.92888229e-07, 1.06342511e-01],
#        [7.39974842e-01, 3.02242023e-06, 1.56189108e+01, ...,
#         1.26591754e-01, 1.02521897e-06, 2.63906812e-01],
#        ...,
#        [5.49448098e-01, 8.87747952e-07, 6.23716586e+00, ...,
#         1.40025121e-01, 2.68052564e-06, 8.77761207e-01],
#        [5.50259024e-01, 9.28990090e-07, 6.02323498e+00, ...,
#         1.39244378e-01, 2.63853559e-06, 9.00001552e-01],
#        [5.49323947e-01, 1.11222459e-06, 6.17594265e+00, ...,
#         1.37683372e-01, 2.70368749e-06, 8.95458556e-01]])
#     samples_id: array([   0,    1,    2, ..., 2566, 2568, 2966], dtype=int64)
#  samples_batch: array([0, 0, 0, ..., 5, 5, 5])
#     samples_it: array([    0,     0,     0, ..., 46183, 46732, 46303])
#      samples_u: array([[0.22027396, 0.74987824, 0.45703489, ..., 0.2177283 , 0.7711356 ,
#         0.69116133],
#        [0.54851847, 0.60196263, 0.23993368, ..., 0.26292169, 0.05306656,
#         0.42714264],
#        [0.73997484, 0.92445147, 0.50625846, ..., 0.12659175, 0.24538257,
#         0.52814539],
#        ...,
#        [0.5494481 , 0.18324582, 0.01248241, ..., 0.14002512, 0.84339799,
#         0.9216418 ],
#        [0.55025902, 0.197566  , 0.00122289, ..., 0.13924438, 0.82822818,
#         0.93589843],
#        [0.54932395, 0.26118909, 0.00926014, ..., 0.13768337, 0.85176571,
#         0.93298625]])
#      samples_n: array([500, 500, 500, ...,   3,   2,   1])
#          logwt: array([-1.00000000e+300, -1.00000000e+300, -1.00000000e+300, ...,
#        -8.01440297e+001, -8.01347434e+001, -8.00851489e+001])
#           logl: array([-1.00000000e+300, -1.00000000e+300, -1.00000000e+300, ...,
#        -3.28473506e+000, -3.27234718e+000, -3.18731474e+000])
#         logvol: array([-1.99800266e-03, -3.99600533e-03, -5.99400799e-03, ...,
#        -7.57576092e+01, -7.61630743e+01, -7.68562215e+01])
#           logz: array([-1.00000000e+300, -1.00000000e+300, -1.00000000e+300, ...,
#        -6.61416384e+001, -6.61416376e+001, -6.61416367e+001])
#        logzerr: array([nan, nan, nan, ..., nan, nan, nan])
#    information: array([-1.99600798e+297, -3.98803192e+297, -5.97607976e+297, ...,
#         5.57630497e+001,  5.57630548e+001,  5.57630602e+001])
#    batch_nlive: array([500, 500, 500, 500, 500, 500])
#   batch_bounds: array([[        -inf,          inf],
#        [-12.35999617,  -9.03808838],
#        [-13.45199429, -12.35743061],
#        [-14.3139984 , -13.44810686],
#        [-14.8765234 ,  -7.51537788],
#        [-15.52392631,  -3.97505829]])
#          bound: [<dynesty.bounding.UnitCube object at 0x000002C5E1D3B518>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1D3B588>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1D3B6D8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1D3B390>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1D3B6A0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1D3B5C0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1CD1400>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1DDF5C0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1D3B2E8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1CD1E10>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1CD1588>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1E35AC8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E19320F0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1CD1710>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932780>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932550>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932C88>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932EF0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932E80>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932A58>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1932940>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920080>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920240>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920588>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920CC0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920B38>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1CD1FD0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920828>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5C7D275C0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5C7D27B38>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5C7D27940>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5C7D27DD8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5C7D27978>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1920A58>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B37160>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B374A8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B37470>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B377F0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B37A58>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B37EB8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B37E10>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B37908>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F02438>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F021D0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F02588>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F02470>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F02CC0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F029E8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F02FD0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B132E8>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B13128>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B13358>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B13780>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5C7D27C18>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B13B38>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B137F0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1F02D30>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1B13C50>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1EC5278>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1EC5780>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1EC5BE0>, <dynesty.bounding.MultiEllipsoid object at 0x000002C5E1EC5908>, <dynesty.bounding.Mul ...
#     bound_iter: array([  0,   0,   0, ..., 728, 728, 728])
#  samples_bound: array([  0,   0,   0, ..., 718, 725, 720])
#          scale: array([1.        , 1.        , 1.        , ..., 0.28910609, 0.28910609,
#        0.28910609])

# %%
print(structure_acmw.slabs())
print(structure_pmw.slabs())
print(structure_d2o.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [ 6.3196585   0.89935074  0.          1.03206211  0.        ]
#  [ 9.93402823  1.54406615  0.          5.72497415  0.        ]
#  [16.66900974 -0.30033068  0.          5.72497415  0.        ]
#  [16.66900974 -0.30033068  0.          5.72497415  0.        ]
#  [ 9.93402823  1.54406615  0.          5.72497415  0.        ]
#  [ 6.3196585   0.89935074  0.          5.72497415  0.        ]]
# [[ 0.          0.          0.          0.          0.        ]
#  [ 6.3196585   1.72646142  0.          1.03206211  0.        ]
#  [ 9.93402823  1.8685872   0.          5.72497415  0.        ]
#  [16.66900974 -0.30031136  0.          5.72497415  0.        ]
#  [16.66900974 -0.30031136  0.          5.72497415  0.        ]
#  [ 9.93402823  1.8685872   0.          5.72497415  0.        ]
#  [ 6.3196585   1.72646142  0.          5.72497415  0.        ]]
# [[ 0.          0.          0.          0.          0.        ]
#  [ 6.3196585   6.10777497  0.          1.03206211  0.        ]
#  [ 9.93402823  3.58761771  0.          5.72497415  0.        ]
#  [16.66900974 -0.30020901  0.          5.72497415  0.        ]
#  [16.66900974 -0.30020901  0.          5.72497415  0.        ]
#  [ 9.93402823  3.58761771  0.          5.72497415  0.        ]
#  [ 6.3196585   6.10777497  0.          5.72497415  0.        ]]

# %%
# structure_d2o
# structure_pmw
plt.plot(*structure_d2o.sld_profile(),label="structure_d2o")
# structure_d2o.plot()
# plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
# plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_pmw.sld_profile(),label="structure_pmw")
# structure_pmw.plot()
plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
plt.xlabel('distance  $(\AA)$')

plt.plot(*structure_acmw.sld_profile(),label="structure_acmw")
# structure_pmw.plot()
# plt.ylabel('SLD ($10^{-6} \AA^{-2})$')
# plt.xlabel('distance  $(\AA)$')
plt.legend()
plt.show();

# %%
if choose==1:
    gobjective.plot(samples=300)
else:
    gobjective.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective1.plot(samples=300)
else:
    objective1.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective2.plot(samples=300)
else:
    objective2.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
if choose==1:
    objective3.plot(samples=300)
else:
    objective3.plot()
# plt.yscale('log')
plt.xlabel('Q')
plt.ylabel('Reflectivity')
plt.legend();

# %%
print("model1: d2o", model1.scale, model1.bkg)
print("model2: pmw", model2.scale, model2.bkg)
# print("model3: acmw", model3.scale, model3.bkg)
# Out:
# model1: d2o <Parameter:    'scale'    , value=0.549179          , bounds=[0, 1]> <Parameter:     'bkg'     , value=1.02725e-06          , bounds=[3.6e-07, 3.24e-06]>
# model2: pmw <Parameter:    'scale'    , value=0.603869          , bounds=[0, 1]> <Parameter:     'bkg'     , value=2.97694e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>

# %%
# print(structure_d2o)

# %%
# print(structure_pmw)

# %%
# print(structure_acmw)

# %%
print(structure_d2o.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [ 6.3196585   6.10777497  0.          1.03206211  0.        ]
#  [ 9.93402823  3.58761771  0.          5.72497415  0.        ]
#  [16.66900974 -0.30020901  0.          5.72497415  0.        ]
#  [16.66900974 -0.30020901  0.          5.72497415  0.        ]
#  [ 9.93402823  3.58761771  0.          5.72497415  0.        ]
#  [ 6.3196585   6.10777497  0.          5.72497415  0.        ]]

# %%
print(structure_pmw.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [ 6.3196585   1.72646142  0.          1.03206211  0.        ]
#  [ 9.93402823  1.8685872   0.          5.72497415  0.        ]
#  [16.66900974 -0.30031136  0.          5.72497415  0.        ]
#  [16.66900974 -0.30031136  0.          5.72497415  0.        ]
#  [ 9.93402823  1.8685872   0.          5.72497415  0.        ]
#  [ 6.3196585   1.72646142  0.          5.72497415  0.        ]]

# %%
print(structure_acmw.slabs())
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [ 6.3196585   0.89935074  0.          1.03206211  0.        ]
#  [ 9.93402823  1.54406615  0.          5.72497415  0.        ]
#  [16.66900974 -0.30033068  0.          5.72497415  0.        ]
#  [16.66900974 -0.30033068  0.          5.72497415  0.        ]
#  [ 9.93402823  1.54406615  0.          5.72497415  0.        ]
#  [ 6.3196585   0.89935074  0.          5.72497415  0.        ]]

# %%
if choose==2:
    # span = [(0,5000),(0,1.5),(0,0.4),(-10**3,10**3)] #span=span
    fig, axes = dyplot.runplot(res1, color='black', mark_final_live=False,
                               logplot=False)

# %%
if choose==2:
    print("max(-ln(X)) =", -min(res1["logvol"])) # -min(res1["logvol"] = max(-ln(X))
    print("max(logz), evidence =", max(res1["logz"]))
# Out:
# max(-ln(X)) = 76.85622145296934
# max(logz), evidence = -66.14163669416253

# %%
#gobjective.varying_parameters()
print("logp:",gobjective.logp())
print("logpost:",gobjective.logpost())
print("model1: d2o", model1.scale, model1.bkg)
print("model2: pmw", model2.scale, model2.bkg)
print("model3: acmw", model3.scale, model3.bkg)
print()
# [[print(i,param.name+":",param.value, param.bounds)] for i,param in enumerate(gobjective.varying_parameters())];
[[print(i,param.name+":",param.value, param.bounds,"logp:", param.logp())] for i,param in enumerate(gobjective.varying_parameters())];
print()
# list(print(p) for p in f_unique(flatten(gobjective.parameters)) if "thi" in p.name or "ap" in p.name);
# volfrac_head = dodab_d2o.vm_heads.value / (dodab_d2o.apm.value *
#                                  dodab_d2o.thickness_heads.value)
# volfrac_tail = dodab_d2o.vm_tails.value / (dodab_d2o.apm.value *
#                                  dodab_d2o.thickness_tails.value)
# print("volfrac_head:",volfrac_head,"volfrac_tail:", volfrac_tail)

volfrac_head = upper_lipid_d2o.vm_heads.value / (upper_lipid_d2o.apm.value *
                                 upper_lipid_d2o.thickness_heads.value)
volfrac_tail = upper_lipid_d2o.vm_tails.value / (upper_lipid_d2o.apm.value *
                                 upper_lipid_d2o.thickness_tails.value)
print("volfrac_head:",volfrac_head,"volfrac_tail:", volfrac_tail)
print(upper_lipid_d2o.vm_heads)
# Out:
# logp: -21.226985478135568
# logpost: -24.097534140968506
# model1: d2o <Parameter:    'scale'    , value=0.549179          , bounds=[0, 1]> <Parameter:     'bkg'     , value=1.02725e-06          , bounds=[3.6e-07, 3.24e-06]>
# model2: pmw <Parameter:    'scale'    , value=0.603869          , bounds=[0, 1]> <Parameter:     'bkg'     , value=2.97694e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
# model3: acmw <Parameter:    'scale'    , value=0.139747          , bounds=[0, 1]> <Parameter:     'bkg'     , value=2.66235e-06          , bounds=[3.46e-07, 3.114e-06]>
#
# 0 scale: 0.549178646784943 [0, 1] logp: 0.0
# 1 bkg: 1.0272508845023736e-06 [3.6e-07, 3.24e-06] logp: 12.75772026381642
# 2 thickness_solution: 6.31965849746087 [6, 25] logp: -2.9444389791664407
# 3 D2O - sld: 6.107774972640325 [5.35, 6.35] logp: 0.0
# 4 rough_preceding_solution: 1.0320621149205638 [0, 20] logp: -2.995732273553991
# 5 bilayer - area_per_molecule: 53.177757799796865 [25, 100] logp: -4.31748811353631
# 6 bilayer - thickness_heads: 9.934028233116852 [1, 30] logp: -3.367295829986474
# 7 bilayer - thickness_tails: 16.66900973973842 [1, 30] logp: -3.367295829986474
# 8 bilayer - roughs: 5.724974152902671 [0, 10] logp: -2.3025850929940455
# 9 bilayer - ratio protein to bilayer: 0.9999986195855468 [0, 1] logp: 0.0
# 10 scale: 0.6038688079816462 [0, 1] logp: 0.0
# 11 bkg: 2.976942137603234e-06 [6.040000000000001e-07, 5.436e-06] logp: 12.24025009733176
# 12 Protein Matched Water - sld: 1.7264614192785315 [1.35, 3.35] logp: -0.6931471805599453
# 13 scale: 0.13974746604598132 [0, 1] logp: 0.0
# 14 bkg: 2.662349072029e-06 [3.46e-07, 3.114e-06] logp: 12.79738552020885
# 15 ACMW - sld: 0.899350737012955 [-0.56, 1] logp: -0.4446858212614458
#
# volfrac_head: 0.6076445692069494 volfrac_tail: 0.9999768025437021
# <Parameter:'bilayer - volume_heads', value=321 (fixed)  , bounds=[-inf, inf]>

# %% [markdown]
# logp: -inf
# logpost: -inf
# model1: d2o <Parameter:    'scale'    , value=0.549101          , bounds=[0.5, 0.65]> <Parameter:     'bkg'     , value=1.18496e-06          , bounds=[3.6e-07, 3.24e-06]>
# model2: pmw <Parameter:    'scale'    , value=0.648749          , bounds=[0.5, 0.65]> <Parameter:     'bkg'     , value=3.17084e-06          , bounds=[6.040000000000001e-07, 5.436e-06]>
#
# 0 scale: 0.5491013265084062 [0.5, 0.65] logp: 1.8971199848858813
# 1 bkg: 1.1849578556868552e-06 [3.6e-07, 3.24e-06] logp: 12.75772026381642
# 2 thickness_solution: 9.0852153265866 [6, 25] logp: -2.9444389791664407
# 3 D2O - sld: 6.113002080900383 [5.35, 6.35] logp: 0.0
# 4 rough_preceding_solution: 2.1693995542364326 [0, 20] logp: -2.995732273553991
# 5 bilayer - area_per_molecule: 56.49160574805357 [25, 100] logp: -4.31748811353631
# 6 bilayer - thickness_heads: 7.518907079603842 [1, 30] logp: -3.367295829986474
# 7 bilayer - thickness_tails: 16.35989423147224 [1, 30] logp: -3.367295829986474
# 8 bilayer - roughs: 6.755636916212968 [0, 10] logp: -2.3025850929940455
# 9 scale: 0.6487485593444838 [0.5, 0.65] logp: 1.8971199848858813
# 10 bkg: 3.170835357649038e-06 [6.040000000000001e-07, 5.436e-06] logp: 12.24025009733176
# 11 Protein Matched Water - sld: 1.6930326557107866 [1.35, 3.35] logp: -0.6931471805599453
#
# volfrac_head: 0.779272510665993 volfrac_tail: 1.0173159080554188

# %% [markdown]
# logp: -10.490609088087473\
# logpost: 17.62268089261965\
# model1: d2o <Parameter:    'scale'    , value=0.549228 +/- 0.00156, bounds=[0.5, 0.65]> <Parameter:     'bkg'     , value=1.22697e-06 +/- 2.68e-07, bounds=[3.6e-07, 3.24e-06]>\
# model2: pmw <Parameter:    'scale'    , value=0.649761 +/- 0.0322, bounds=[0.5, 0.65]> <Parameter:     'bkg'     , value=3.0741e-06 +/- 8.74e-08, bounds=[6.040000000000001e-07, 5.436e-06]>\
#
# 0 scale: 0.5492281647969319 [0.5, 0.65] logp: 1.8971199848858813\
# 1 bkg: 1.226965651203409e-06 [3.6e-07, 3.24e-06] logp: 12.75772026381642\
# 2 thickness_solution: 8.305179241524081 [6, 25] logp: -2.9444389791664407\
# 3 D2O - sld: 6.112183186229328 [5.35, 6.35] logp: 0.0\
# 4 rough_preceding_solution: 2.2877953415685726 [0, 20] logp: -2.995732273553991\
# 5 bilayer - area_per_molecule: 56.93865886215209 [25, 100] logp: -4.31748811353631\
# 6 bilayer - thickness_heads: 7.97904560551147 [1, 30] logp: -3.367295829986474\
# 7 bilayer - thickness_tails: 16.513065027262286 [1, 30] logp: -3.367295829986474\
# 8 bilayer - roughs: 6.0609769145636285 [0, 10] logp: -2.3025850929940455\
# 9 scale: 0.6497612329758051 [0.5, 0.65] logp: 1.8971199848858813\
# 10 bkg: 3.074103742304922e-06 [6.040000000000001e-07, 5.436e-06] logp: 12.24025009733176\
# 11 Protein Matched Water - sld: 1.6875704213514187 [1.35, 3.35] logp: -0.6931471805599453\
#
# volfrac_head: 0.7285675312015728 volfrac_tail: 0.9999662036993213

# %%
print(#upper_lipid_d2o.total_vm(),"\n",
# upper_lipid_d2o.sld_r(),"\n",
float(upper_lipid_d2o.b_heads_real) / float(upper_lipid_d2o.vm_heads.value) * 1.e6,"\n",
float(upper_lipid_d2o.b_tails_real) / float(upper_lipid_d2o.vm_tails.value) * 1.e6,"\n",
upper_lipid_d2o.b_heads_real,"\n",
upper_lipid_d2o.b_tails_real,"\n")#,
# float(dodab_d2o.b_heads_real) / float(dodab_d2o.vm_heads.value) * 1.e6,"\n",
# float(dodab_d2o.b_tails_real) / float(dodab_d2o.vm_tails.value) * 1.e6,"\n",
# dodab_d2o.b_heads_real,"\n",
# dodab_d2o.b_tails_real,"\n")#,
# upper_lipid_d2o.protien_frac_in_head(),"\n",
# upper_lipid_d2o.protien_frac_in_tail(),"\n",
# upper_lipid_d2o.vm_head(),"\n",
# upper_lipid_d2o.vm_tail(),"\n",
# upper_lipid_d2o.vm_heads,"\n",
# upper_lipid_d2o.vm_tails,"\n",
# upper_lipid_d2o.PLRatio,"\n",
# upper_lipid_d2o.vm_mscl,"\n")
# upper_lipid_d2o.total_vm(),"\n")
# print(upper_lipid_d2o.d2o_mol_fraction_head(),upper_lipid_pmw.d2o_mol_fraction_head())
# Out:
# 1.9603582554517136
#  -0.300361010830325
#  <Parameter:'bilayer - b_heads_real', value=0.000629275 (fixed)  , bounds=[-inf, inf]>
#  <Parameter:'bilayer - b_tails_real', value=-0.00026624 (fixed)  , bounds=[-inf, inf]>

# %% [markdown]
# <!-- I believe correct values, leaflet roughness between head and tail is the same as the roughness preceeding the leaflet\
# class used is a modified version of the LipidLeaflet class native to refnx, its in the file\
# "protein" and called "LipidLeafletWithProtien"\
# volumes of head and tails are indirectly varied by changes in waters per head/tail\
# so the tails do not change volume\
# 0 scale: 0.5521883304658243 [0.5, 0.6]\
# 1 bkg: 3.8668280301251303e-07 [3.6e-07, 3.24e-06]\
# 2 thickness_solution: 10.788185214150985 [6, 25]\
# 3 D2O - sld: 6.120774383877097 [5.35, 6.35]\
# 4 rough_preceding_solution: 3.939327435493368 [0, 20]\
# 5 bilayer - area_per_molecule: 149.83843268748353 [60, 150]\
# 6 bilayer - thickness_heads: 2.2131024442953855 [1, 30]\
# 7 bilayer - thickness_tails: 19.19114563662231 [1, 30]\
# 8 bilayer - rough_top: 0.15555337800548585 [0, 10]\
# 9 bilayer - Waters Per Head: 0.017922237590786594 [0, 20]\
# 10 bilayer - Waters Per Tail: 0.02927203409960022 [0, 10]\
# 11 bilayer - ratio protein to bilayer: 0.7498017765068212 [0.25, 0.75]\
# 12 Protrusion - protrusion thickness: 6.090177488208205 [5, 100]\
# 13 Protrusion - protrusion roughness: 7.445463122283828 [0, 20]\
# 14 Protrusion - protrusion volfrac: 0.9963095809664922 [0, 1]\
# 15 scale: 0.5990025735918081 [0.5, 0.6]\
# 16 bkg: 3.5880504074107574e-06 [6.040000000000001e-07, 5.436e-06]\
# 17 Protein Matched Water - sld: 1.757984633375042 [1.35, 3.35]\
# 18 scale: 0.5907367476195101 [0.5, 0.6]\
# 19 bkg: 2.831535701386751e-06 [3.46e-07, 3.114e-06]\
# 20 ACMW - sld: 0.4132210895757328 [-0.56, 1] -->

# %%
if choose==2:
    labels = [param.name for param in gobjective.varying_parameters()]

    fig, axes = dyplot.traceplot(res1, labels = labels, truths=[param.value for param in gobjective.varying_parameters()],
                                 show_titles=True, trace_cmap='plasma',
                                 quantiles=[0.025, 0.5, 0.975])
    fig.tight_layout()

# %%
# if choose==2:
#     labels = [param.name for param in gobjective.varying_parameters()]
# #     dim = [0,2,3,4,5,6,7,8,9,1]
#     fig, axes = dyplot.cornerpoints(res1,labels = labels,truths=[param.value for param in gobjective.varying_parameters()],
#                                  #show_titles=True,
#                                  #trace_cmap='plasma',
#                                  #quantiles=[0.025, 0.5, 0.975]
#                                    )
#     fig.tight_layout()

# %%
# if choose==2:
#     labels = [param.name for param in gobjective.varying_parameters()]

#     fig, axes = dyplot.cornerplot(res1, labels = labels,truths=[param.value for param in gobjective.varying_parameters()],
#                                  #show_titles=True,
#                                  #trace_cmap='plasma',
#                                  #quantiles=[0.025, 0.5, 0.975]
#                                    )
#     fig.tight_layout()

# %%
# if choose==2:
#     labels = [param.name for param in gobjective.varying_parameters()if not "bkg" in param.name]
#     dim = [0,2,3,4,5,6,7,8,9,11]
#     fig, axes = dyplot.cornerpoints(res1,dims=dim, labels = labels,truths=[param.value for param in gobjective.varying_parameters() if not "bkg" in param.name],
#                                  #show_titles=True,
#                                  #trace_cmap='plasma',
#                                  #quantiles=[0.025, 0.5, 0.975]
#                                    )
#     fig.tight_layout()

# %%
# if choose==2:
#     labels = [param.name for param in gobjective.varying_parameters() if not "bkg" in param.name]
# #     labels = [label for label in labels ]
#     dim = [0,2,3,4,5,6,7,8,9,11]
#     fig, axes = dyplot.cornerplot(res1,dims=dim, labels = labels,truths=[param.value for param in gobjective.varying_parameters() if not "bkg" in param.name],
#                                  #show_titles=True,
#                                  #trace_cmap='plasma',
#                                  #quantiles=[0.025, 0.5, 0.975]
#                                    )
#     fig.tight_layout()
